# %%
import numpy
import matplotlib.pyplot as plt
import time
import pandas as pd

dfrm=pd.read_csv("student.csv")
name=dfrm.iloc[0:,0]
marks=dfrm.iloc[0:,1]
e=(0.2,0,0,0)
plt.pie(marks,autopct="%1.1f%%",labels=name,explode=e,shadow="true")
#print(dir(plt.pie))
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0c3cd6d0f0>,
# ...
#  [Text(0.8606333367692199, 0.9743255408955873, 'sneha'),
#   Text(-0.8448884311395064, 0.7043887697334646, 'yash'),
#   Text(-0.7590868934314098, -0.7961074602217038, 'sid'),
#   Text(0.7741062627049833, -0.7815110325778668, 'mansi')],
#  [Text(0.5296205149349046, 0.5995849482434383, '27.0%'),
#   Text(-0.46084823516700346, 0.3842120562182534, '23.9%'),
#   Text(-0.41404739641713256, -0.434240432848202, '23.9%'),
#   Text(0.4222397796572636, -0.42627874504247276, '25.2%')])
